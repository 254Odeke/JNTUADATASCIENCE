# %% [markdown]
# ## Python:
#
# ### Introduction to Python:
#
# * Python discovered by Guido Van Russom in 1994with version 1
# * Version 2 is introduced in 2000
# * Version 3 is introduced in 2008
# * Version 3.8 is introduced in 2019
# * Python is intrepreted language.That means the compiling is done by the python programming without any separate source.So,that the code is executed line by line.
# * It is high level language means the code can be understandable by a human.
# * Python general purpose language.
#
#
# #### Why Python?
#
# * The programming in python is very easy to learn and develope.
# * It Supports Object oriented programming(OOPs)
# * It is platform independent.
# * It is having more number of advanced libraries.
# * Python is open source and having a huge developer community.
# * Used to develope web applications,Machine learning algorithms,Data science,IoT devices and Artificial Intelligence.
#
# #### Advantages of Python:
#
# * It is very easy to use.
# * Python is just like English language,so that easy to understand.
# * Code will be executed line by line.
# * Time will be saved due to line by line.
# * All advanced technologies are using this python programming.
#
#
# #### Idles for Python:
#
# * Basic Idles like Original Idle of python,sublimetext,pycharm,notepad++,visuial studio etc.
# * Jupyter Notebook
# * Google colab
#
# #### Why Only Jupyter?
#
# * By default all libraries are installed.
# * For using the text and code at the same place we can use jupyter notebook
# * Jupyter supports all the advanced programming.
# * Most of the MNC's are using Jupyter as their Idle.
#
# ### Jupyter Notebook:
#
# * The programming used in Jupyter Notebook is called as Literature Programming.
# * The text we are using is called as Markdown
# * Converting a cell into markdown cell--- esc + m
# * converting a cell into code cell -- esc + y
# * Running the cell ---- Shift + enter
# * To run and insert a cell below --- alt + enter

# %% [markdown]
# # markdown in Jupyter:
#
# #  --- Heading with the highest size.
# ## --- 2 nd highest
# ### ---  3rd
# #### --- 4th
# ##### ---  5 th
# ###### --- 6th
#
# * Hashtag is used to set the size of the title .The siize can be varied within 6 hashes.
# * *Italic* --- To get italic text one astrick at the start and at the end without any spaces.
# * **Bold** --- To get Bold text two astricks at the start and at the end without any spaces
# * ***Bold and Italic*** --- To get bold along with the Italic,three astricks at the start and at the end without spaces.
# * ~~Strike off~~ --- To get strike off text use the double ~ at the end and at the start without any spaces
#
# * Astrick with space gives points.
#     * Subpoint
#         * Subpoint in subpoint
#
# 1. ordered lists
#     + item
#     + item
# 2. unordered lists
#
# < img src = "imageaddress" >  --- inserting the images into the jupyter notebook
#
# <img src = "https://image.shutterstock.com/image-photo/beautiful-blooming-pink-gerbera-daisy-260nw-1647166909.jpg">
#
# * Using the different programming codes in the jupyter can be done by three ~ symbols and programming name at the start and only ~ symbols three times at the end.
#
# ~~~python
# print("Python code in markdown")
# ~~~
#
# ~~~c
# printf("welcome")
# ~~~
#
# * Creating table:  Use | symbol for making the column division and for --- row division
#
# col1|col2|col3
# ----|----|----
# Data|Data|Data
# Data|Data|Data
#
# * [Google]("https://www.google.com/")
